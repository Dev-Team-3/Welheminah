# %%
import pandas as pd
data = {'Category':['Chips','Chips','Chips','Chips','Chips','','Coldrinks','Coldrinks','Coldrinks','Coldrinks','Coldrinks','','Chocolates','Chocolates','Chocolates','Chocolates','Chocolates','','Pies','Pies','Pies','Pies','Pies','','Fruits','Fruits','Fruits','Fruits','Fruits','','Cupcakes','Cupcakes','Cupcakes','Cupcakes','Cupcakes','','Veggies','Veggies','Veggies','Veggies','Veggies','','Biscuits','Biscuits','Biscuits','Biscuits','Biscuits'],'Product':['Simba', 'Lays', 'Doritos', 'Nik Nats','Fritos','','Coke','Fanta','Sprite','Dry Lemon','Stoney','','Cadbury','Tex','Kit-kat','Linds','TV Bar','','Pepper Steak','Chicken','Spinach','Burger','Curry','','Apple','Pear','Orange','Banana','Grapes','','Vanilla','Chocolate','Carrot','Oreo','Red Velvet','','Spinach','Cabbage','Carrot','Cucumber','Tomato','','Tennis','Oreo','Digestives','Marie','Fingers'],'Price':[28,14,11,12,15,'',15,11,12,14,10,'',12,11,11,20,12,'',13,13,13,13,13,'',2,3,3,2,15,'',13,14,13,13,14,'',12,10,10,12,10,'',12,13,13,14,12],'Stock(Quantity)':[30,40,20,30,50,'',50,30,30,30,20,'',20,30,20,20,10,'',30,30,30,30,30,'',40,40,40,40,20,'',20,20,20,20,20,'',10,20,20,20,30,'',20,20,30,20,40],'Brand':['Simba','Simba','Simba','Simba','Simba','','Coca-Cola','Coca-Cola','Coca-Cola','Shweppes','Coca-Cola','','Dairymilk','Dairymilk','Dairymilk','Linds','Beacon','','Pieman','Pieman','Pieman','Pieman','Pieman','','Trucape','Trucape','Trucape','Zests','Suiderland','','Ouma','Ouma','Ouma','Ouma','Ouma','','Organic girl','Organic girl','Bolt house','Cuts','ZZ2','','Bakers','Nabisco','McVities','Bakers','Bakers']}
df = pd.DataFrame(data)
print (df)
# Out:
#       Category       Product Price Stock(Quantity)         Brand
# 0        Chips         Simba    28              30         Simba
# 1        Chips          Lays    14              40         Simba
# 2        Chips       Doritos    11              20         Simba
# 3        Chips      Nik Nats    12              30         Simba
# 4        Chips        Fritos    15              50         Simba
# 5
# 6    Coldrinks          Coke    15              50     Coca-Cola
# 7    Coldrinks         Fanta    11              30     Coca-Cola
# 8    Coldrinks        Sprite    12              30     Coca-Cola
# 9    Coldrinks     Dry Lemon    14              30      Shweppes
# 10   Coldrinks        Stoney    10              20     Coca-Cola
# 11
# 12  Chocolates       Cadbury    12              20     Dairymilk
# 13  Chocolates           Tex    11              30     Dairymilk
# 14  Chocolates       Kit-kat    11              20     Dairymilk
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=47, step=1)

# %%
df.columns
# Out:
# Index(['Category', 'Product', 'Price', 'Stock(Quantity)', 'Brand'], dtype='object')

# %%
df
# Out:
#       Category       Product Price Stock(Quantity)         Brand
# 0        Chips         Simba    28              30         Simba
# 1        Chips          Lays    14              40         Simba
# 2        Chips       Doritos    11              20         Simba
# 3        Chips      Nik Nats    12              30         Simba
# 4        Chips        Fritos    15              50         Simba
# 5
# 6    Coldrinks          Coke    15              50     Coca-Cola
# 7    Coldrinks         Fanta    11              30     Coca-Cola
# 8    Coldrinks        Sprite    12              30     Coca-Cola
# 9    Coldrinks     Dry Lemon    14              30      Shweppes
# 10   Coldrinks        Stoney    10              20     Coca-Cola
# 11
# 12  Chocolates       Cadbury    12              20     Dairymilk
# 13  Chocolates           Tex    11              30     Dairymilk
# 14  Chocolates       Kit-kat    11              20     Dairymilk
# ...

# %%
df = pd.DataFrame(data)
print (df[2:4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-99c388694d16> in <module>
# ----> 1 df = pd.DataFrame(data)
#       2 print (df[2:4])
#
# NameError: name 'pd' is not defined

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt  
Data = {'Price': [28,14,11,12,15,'',15,11,12,14,10,'',12,11,11,20,12,'',13,13,13,13,13,'',2,3,3,2,15,'',13,14,13,13,14,'',12,10,10,12,10,'',12,13,13,14,12],
        'Stock(Quantity)': [30,40,20,30,50,'',50,30,30,30,20,'',20,30,20,20,10,'',30,30,30,30,30,'',40,40,40,40,20,'',20,20,20,20,20,'',10,20,20,20,30,'',20,20,30,20,40]}
  
df = DataFrame(Data,columns = ['Price','Stock(quantity)'])
df.plot(x ='Price', y ='Stock(quantity)', kind ='bar')
plt.show()

# %%
# %matplotlib inline

# %%
#Graph for the Product and Stock
import matplotlib.pyplot as plt
import pandas as pd
x = [28,14,11,12,15]
y = [30,40,20,30,50]
plt.plot(x,y)
plt.xlabel('Chips')
plt.ylabel('Stock(Quantity)')
plt.show()

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
y =
